# %% [markdown]
# <a href="https://colab.research.google.com/github/jatinchhabra2516-cell/Machine-Learning/blob/main/Machine_learning_lab_4_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3rd Februrary 2026
# Topic 2: Linear Regression

# %% [markdown]
# in linear regression one variable need to depend on other.
# it is a statistical method.
# target variable can be one or more than one.

# %%
import numpy as np
import pandas as pd

x= np.array ([1,3,5,7,8,9,10,15])
y= np.array ([10,20,30,40,50,60,70,80])

# %%
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

print(Pearson_correlation(x,y))
print(Pearson_correlation(x,x))
print(Pearson_correlation(y,y))
print(Pearson_correlation(y,x))
 #it is strong correlation because it is close to 1
# Out:
# 0.974894414261588
# 1.0
# 1.0
# 0.974894414261588

# %%
x1= np.array ([1,3,5,7,8,9,10,15])
y1= np.array ([80,70,60,50,40,30,20,10])
def Pearson_correlation(X1,Y1):
    if len(X1)==len(Y1):
        Sum_x1y1 = sum((X1-X1.mean())*(Y1-Y1.mean()))
        Sum_x1_squared = sum((X1-X1.mean())**2)
        Sum_y1_squared = sum((Y1-Y1.mean())**2)
        corr = Sum_x1y1/ np.sqrt(Sum_x1_squared * Sum_y1_squared)
    return corr

print(Pearson_correlation(x1,y1))
print(Pearson_correlation(x1,x1))
print(Pearson_correlation(y1,y1))
print(Pearson_correlation(y1,x1))
# Out:
# -0.974894414261588
# 1.0
# 1.0
# -0.974894414261588

# %%
x2= np.array ([1,5,4,9,16,7])
y2= np.array ([20,80,44,50,60,5])
def Pearson_correlation(X1,Y1):
    if len(X1)==len(Y1):
        Sum_x2y2 = sum((X1-X1.mean())*(Y1-Y1.mean()))
        Sum_x2_squared = sum((X1-X1.mean())**2)
        Sum_y2_squared = sum((Y1-Y1.mean())**2)
        corr = Sum_x2y2/ np.sqrt(Sum_x2_squared * Sum_y2_squared)
    return corr

print(Pearson_correlation(x2,y2))
print(Pearson_correlation(x2,x2))
print(Pearson_correlation(y2,y2))
print(Pearson_correlation(y2,x2))
# Out:
# 0.32464548791752923
# 1.0
# 1.0
# 0.32464548791752923

# %%
df= pd.read_csv('insurance.csv')
x4=np.array(df.bmi)
y4=np.array(df.charges)
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_x4y4 = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x4_squared = sum((X-X.mean())**2)
        Sum_y4_squared = sum((Y-Y.mean())**2)
        corr = Sum_x4y4 / np.sqrt(Sum_x4_squared * Sum_y4_squared)
    return corr

print(Pearson_correlation(x4,y4))
# Out:
# 0.198340968833629

# %%
x5=np.array(df.bmi)
y5=np.array(df.age)
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_x5y5 = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x5_squared = sum((X-X.mean())**2)
        Sum_y5_squared = sum((Y-Y.mean())**2)
        corr = Sum_x5y5 / np.sqrt(Sum_x5_squared * Sum_y5_squared)
    return corr

print(Pearson_correlation(x5,y5))
# Out:
# 0.10927188154853491

# %%
x6=np.array(df.bmi)
y6=np.array(df.children)
def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_x6y6 = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x6_squared = sum((X-X.mean())**2)
        Sum_y6_squared = sum((Y-Y.mean())**2)
        corr = Sum_x6y6 / np.sqrt(Sum_x6_squared * Sum_y6_squared)
    return corr

print(Pearson_correlation(x6,y6))
# Out:
# 0.012758900820673822

# %%
df_new=pd.read_csv('insurance2.csv')
corre=df_new.corr(method='pearson')
print(corre)
#TO FIND THE PEARSON CORRELATION MATRIX IT GIVES CORRELATION  OF EVERY NUMERIC VALUE WITH OTHER NUMERIC VALUE
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %% [markdown]
# THE CORRELATION OF BMI WITH AGE=
# THE CORRELATION OF BMI WITH CHILDREN=0.012758900820673822
# THE CORRELATION OF BMI WITH CHARGES=
